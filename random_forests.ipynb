# %%
import numpy as np
import pandas as pd
from pydataset import data
import env as env
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix
import acquire as acq
import prepare as prep
import matplotlib.pyplot as plt
import seaborn as sns
from termcolor import colored
import os
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier


from io import StringIO

# %% [markdown]
# Load Dataset

# %%
titanic = acq.get_titanic_data()
# Out:
# csv file found and loaded

# %% [markdown]
# Prep dataset

# %%
#titanic = prep.prep_titanic(titanic)

# %%
dummy_df = pd.get_dummies(data=titanic[['sex']], drop_first=True)
dummy_df.head()
# Out:
#    sex_male
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
titanic = pd.concat([titanic, dummy_df], axis=1)
titanic.dtypes
# Out:
# passenger_id                 int64
# survived                     int64
# pclass                       int64
# sex                         object
# sibsp                        int64
# parch                        int64
# fare                       float64
# embark_town                 object
# alone                        int64
# sex_male                     uint8
# embark_town_Queenstown       uint8
# embark_town_Southampton      uint8
# sex_male                     uint8
# dtype: object

# %%
train, validate, test = prep.split_function(titanic, 'survived')

# %%
train.shape
# Out:
# (534, 13)

# %%
validate.shape
# Out:
# (178, 13)

# %%
test.shape
# Out:
# (179, 13)

# %%
train
# Out:
#      passenger_id  survived  pclass     sex  sibsp  parch      fare  \
# 455           455         1       3    male      0      0    7.8958
# 380           380         1       1  female      0      0  227.5250
# 492           492         0       1    male      0      0   30.5000
# 55             55         1       1    male      0      0   35.5000
# 243           243         0       3    male      0      0    7.1250
# ..            ...       ...     ...     ...    ...    ...       ...
# 695           695         0       2    male      0      0   13.5000
# 128           128         1       3  female      1      1   22.3583
# 636           636         0       3    male      0      0    7.9250
# 222           222         0       3    male      0      0    8.0500
# 496           496         1       1  female      1      0   78.2667
#
#      embark_town  alone  sex_male  embark_town_Queenstown  \
# 455    Cherbourg      1         1                       0
# 380    Cherbourg      1         0                       0
# 492  Southampton      1         1                       0
# 55   Southampton      1         1                       0
# 243  Southampton      1         1                       0
# ..           ...    ...       ...                     ...
# 695  Southampton      1         1                       0
# 128    Cherbourg      0         0                       0
# 636  Southampton      1         1                       0
# 222  Southampton      1         1                       0
# 496    Cherbourg      0         0                       0
#
#      embark_town_Southampton  sex_male
# 455                        0         1
# 380                        0         0
# 492                        1         1
# 55                         1         1
# 243                        1         1
# ..                       ...       ...
# 695                        1         1
# 128                        0         0
# 636                        1         1
# 222                        1         1
# 496                        0         0
#
# [534 rows x 13 columns]

# %%
titanic.shape
titanic.head()
# Out:
#    passenger_id  survived  pclass     sex  sibsp  parch     fare  embark_town  \
# 0             0         0       3    male      1      0   7.2500  Southampton
# 1             1         1       1  female      1      0  71.2833    Cherbourg
# 2             2         1       3  female      0      0   7.9250  Southampton
# 3             3         1       1  female      1      0  53.1000  Southampton
# 4             4         0       3    male      0      0   8.0500  Southampton
#
#    alone  sex_male  embark_town_Queenstown  embark_town_Southampton  sex_male
# 0      0         1                       0                        1         1
# 1      0         0                       0                        0         0
# 2      1         0                       0                        1         0
# 3      0         0                       0                        1         0
# 4      1         1                       0                        1         1

# %%
y = train
y.head()

X = y.drop(columns= 'survived')
X.head()
# Out:
#      passenger_id  pclass     sex  sibsp  parch      fare  embark_town  alone  \
# 455           455       3    male      0      0    7.8958    Cherbourg      1
# 380           380       1  female      0      0  227.5250    Cherbourg      1
# 492           492       1    male      0      0   30.5000  Southampton      1
# 55             55       1    male      0      0   35.5000  Southampton      1
# 243           243       3    male      0      0    7.1250  Southampton      1
#
#      sex_male  embark_town_Queenstown  embark_town_Southampton  sex_male
# 455         1                       0                        0         1
# 380         0                       0                        0         0
# 492         1                       0                        1         1
# 55          1                       0                        1         1
# 243         1                       0                        1         1

# %%
y_train = y
X_train = X

# %%
X_train['sex'] = X_train['sex'].apply(lambda x: 1 if x == 'male' else 0)
X_train = X_train.drop(columns='embark_town')

# %%
X_train.head()
# Out:
#      passenger_id  pclass  sex  sibsp  parch      fare  alone  sex_male  \
# 455           455       3    1      0      0    7.8958      1         1
# 380           380       1    0      0      0  227.5250      1         0
# 492           492       1    1      0      0   30.5000      1         1
# 55             55       1    1      0      0   35.5000      1         1
# 243           243       3    1      0      0    7.1250      1         1
#
#      embark_town_Queenstown  embark_town_Southampton  sex_male
# 455                       0                        0         1
# 380                       0                        0         0
# 492                       0                        1         1
# 55                        0                        1         1
# 243                       0                        1         1

# %%
X_train.head()
# Out:
#      passenger_id  pclass  sex  sibsp  parch      fare  alone  sex_male  \
# 455           455       3    1      0      0    7.8958      1         1
# 380           380       1    0      0      0  227.5250      1         0
# 492           492       1    1      0      0   30.5000      1         1
# 55             55       1    1      0      0   35.5000      1         1
# 243           243       3    1      0      0    7.1250      1         1
#
#      embark_town_Queenstown  embark_town_Southampton  sex_male
# 455                       0                        0         1
# 380                       0                        0         0
# 492                       0                        1         1
# 55                        0                        1         1
# 243                       0                        1         1

# %%
clf = DecisionTreeClassifier()
clf
# Out:
# DecisionTreeClassifier()

# %%
y_train.survived.value_counts()
# Out:
# 0    329
# 1    205
# Name: survived, dtype: int64

# %%
X_train.dtypes
# Out:
# passenger_id                 int64
# pclass                       int64
# sex                          int64
# sibsp                        int64
# parch                        int64
# fare                       float64
# alone                        int64
# sex_male                     uint8
# embark_town_Queenstown       uint8
# embark_town_Southampton      uint8
# sex_male                     uint8
# dtype: object

# %%
X_train = pd.DataFrame.dropna(X_train)

# %%
X_train = X_train.dropna(axis= 'rows')
X_train = X_train.dropna()
X_train
# Out:
#      passenger_id  pclass  sex  sibsp  parch      fare  alone  sex_male  \
# 455           455       3    1      0      0    7.8958      1         1
# 380           380       1    0      0      0  227.5250      1         0
# 492           492       1    1      0      0   30.5000      1         1
# 55             55       1    1      0      0   35.5000      1         1
# 243           243       3    1      0      0    7.1250      1         1
# ..            ...     ...  ...    ...    ...       ...    ...       ...
# 695           695       2    1      0      0   13.5000      1         1
# 128           128       3    0      1      1   22.3583      0         0
# 636           636       3    1      0      0    7.9250      1         1
# 222           222       3    1      0      0    8.0500      1         1
# 496           496       1    0      1      0   78.2667      0         0
#
#      embark_town_Queenstown  embark_town_Southampton  sex_male
# 455                       0                        0         1
# 380                       0                        0         0
# 492                       0                        1         1
# 55                        0                        1         1
# 243                       0                        1         1
# ..                      ...                      ...       ...
# 695                       0                        1         1
# 128                       0                        0         0
# 636                       0                        1         1
# 222                       0                        1         1
# 496                       0                        0         0
#
# [534 rows x 11 columns]

# %%
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 clf.fit(X_train, y_train)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:172, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     170 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     171 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 172 X, y = self._validate_data(
#     173     X, y, validate_separately=(check_X_params, check_y_params)
#     174 )
#     175 if issparse(X):
#     176     X.sort_indices()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/base.py:594, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     592     if "estimator" not in check_y_params:
#     593         check_y_params = {**default_check_params, **check_y_params}
# --> 594     y = check_array(y, input_name="y", **check_y_params)
#     595 else:
#     596     X, y = check_X_y(X, y, **check_params)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:151, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#     150     if _object_dtype_isnan(X).any():
# --> 151         raise ValueError("Input contains NaN")
#
# ValueError: Input contains NaN

# %% [markdown]
# Fit the Random Forest classifier to your training sample and transform (i.e. make predictions on the training sample) setting the random_state accordingly and setting min_samples_leaf = 1 and max_depth = 10.

# %% [markdown]
# Evaluate your results using the model score, confusion matrix, and classification report.

# %% [markdown]
# Print and clearly label the following: Accuracy, true positive rate, false positive rate, true negative rate, false negative rate, precision, recall, f1-score, and support.

# %% [markdown]
# Run through steps increasing your min_samples_leaf and decreasing your max_depth.

# %% [markdown]
# What are the differences in the evaluation metrics? Which performs better on your in-sample data? Why?
